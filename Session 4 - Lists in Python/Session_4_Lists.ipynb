# %%
"""
Lists :
1. What are lists?
2. Lists Vs Array
3. Characterstics of a List
4. How to create a list
5. Access items from a List
6. Editing items in a List
7. Deleting Items from a List
8. Operations on Lists
9. Functions on Lists 
"""

# %% [markdown]
# ## What are Lists?
# #### List is a data type where you can Store multiple items under 1 name. More technically, lists act like dynamic arrays which means you can add more items on the fly.
# ![image.png](attachment:image.png)
#
# #### Why Lists are required in Programming?
#
# ## Array vs Lists
# 1. Fixed vs Dynamic Size<br>
# 2. Convenience -> Hetrogeneous<br>
# 3. Speed of Execution<br>
# 4. Memory<br>
#
# ##### Array is homogeneous i.e variable with same data type can be stored. Where as Lists are Hetrogeneous i.e values with different data type can be stored.

# %%
a = 2 
print(id(2))       #id gives us the memory address
# Out:
# 140716909382104
